# %%
# Importo mi Clase con las constantes declaradas con las rutas y algunos mensajes que utilizare 
from Business.constantes import MagicString
from Business.business_logic_general import General
from Business.business_vehicles import Vehicles

# %%
# Lectura de nuestro recurso CSV.
Datos = General.leer_datos_csv(MagicString.VEHICULOS_RUTA)

# %%
# Realizo la lectura de los datos para el analisis exploratorio
General.realizar_lectura_datos_analisis(Datos,MagicString.CONFIGURACION_GENERAL_CANTIDAD_REGISTROS)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm      5
# ...

# %%
# Verifico los valores que tiene las columnas fuel, transmission, owner 
Vehicles.ver_detalles_columnas_texto(Datos)
# Out:
# ['Diesel' 'Petrol' 'LPG' 'CNG']
# ...
# ['Manual' 'Automatic']
# ...
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']
# ...
# ['74 bhp' '103.52 bhp' '78 bhp' '90 bhp' '88.2 bhp' '81.86 bhp' '57.5 bhp'
#  '37 bhp' '67.1 bhp' '68.1 bhp' '108.45 bhp' '60 bhp' '73.9 bhp' nan
#  '67 bhp' '82 bhp' '88.5 bhp' '46.3 bhp' '88.73 bhp' '64.1 bhp' '98.6 bhp'
#  '88.8 bhp' '83.81 bhp' '83.1 bhp' '47.3 bhp' '73.8 bhp' '34.2 bhp'
#  '35 bhp' '81.83 bhp' '40.3 bhp' '121.3 bhp' '138.03 bhp' '160.77 bhp'
#  '117.3 bhp' '116.3 bhp' '83.14 bhp' '67.05 bhp' '168.5 bhp' '100 bhp'
#  '120.7 bhp' '98.63 bhp' '175.56 bhp' '103.25 bhp' '171.5 bhp' '100.6 bhp'
#  '174.33 bhp' '187.74 bhp' '170 bhp' '78.9 bhp' '88.76 bhp' '86.8 bhp'
#  '108.495 bhp' '108.62 bhp' '93.7 bhp' '103.6 bhp' '98.59 bhp' '189 bhp'
#  '67.04 bhp' '68.05 bhp' '58.2 bhp' '82.85 bhp' '81.80 bhp' '73 bhp'
#  '120 bhp' '94.68 bhp' '160 bhp' '65 bhp' '155 bhp' '69.01 bhp'
# ...

# %%
# Convierto estos datos de texto a datos numericos para poder sacar datos estadisticos de esto
Datos_modificados = Vehicles.realizar_ajustes_en_datos(Datos)

# %%
Datos_modificados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   int32
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   int32
#  7   owner          6717 non-null   int32
#  8   mileage        6717 non-null   float64
#  9   engine         6717 non-null   int32
#  10  max_power      6717 non-null   float64
#  11  torque         6717 non-null   object
#  12  seats          6717 non-null   int32
# dtypes: float64(2), int32(5), int64(3), object(3)
# memory usage: 603.5+ KB

# %%
# Descripcion de los Datos.
General.describir_datos_csv(Datos_modificados)
# Out:
#        year  selling_price  km_driven  fuel  transmission  owner  mileage  \
# count  6717           6717       6717  6717          6717   6717     6717
# mean   2014         526386      73398     1             0      2       20
# std       4         523550      58703     1             0      1        4
# min    1994          29999          1     1             0      1        9
# 25%    2011         250000      38000     1             0      1       17
# 50%    2014         420000      68203     1             0      1       19
# 75%    2017         650000     100000     2             0      2       22
# max    2020       10000000    2360457     4             1      5       42
#
#        engine  max_power  seats
# count    6717       6717   6717
# mean     1431         88      5
# std       493         32      1
# min       624         33      2
# 25%      1197         67      5
# 50%      1248         82      5
# 75%      1498        100      5
# max      3604        400     14

# %%
# Realizo la lectura de los datos para verificar los ajustes realiados a los datos.
General.realizar_lectura_datos_analisis(Datos_modificados,MagicString.CONFIGURACION_GENERAL_CANTIDAD_REGISTROS)
# Out:
#       name  year  selling_price  km_driven  fuel seller_type  transmission  \
# 0   Maruti  2014         450000     145500     1  Individual             0
# 1    Skoda  2014         370000     120000     1  Individual             0
# 2    Honda  2006         158000     140000     2  Individual             0
# 3  Hyundai  2010         225000     127000     1  Individual             0
# 4   Maruti  2007         130000     120000     2  Individual             0
#
#    owner  mileage  engine  max_power                    torque  seats
# 0      1       23    1248         74            190Nm@ 2000rpm      5
# 1      2       21    1498        104       250Nm@ 1500-2500rpm      5
# 2      3       18    1497         78     12.7@ 2,700(kgm@ rpm)      5
# 3      1       23    1396         90  22.4 kgm at 1750-2750rpm      5
# 4      1       16    1298         88     11.5@ 4,500(kgm@ rpm)      5

# %%
Datos_para_entrenamiento = Datos_modificados.copy()

#Remuevo las columnas name, seller_type y torque. Ya que estas solo brindan valores informativos y no son necesarios para el analisis estadistico.
Datos_para_entrenamiento.drop(MagicString.VEHICULOS_HEADER_NAME, axis=1, inplace=True)
Datos_para_entrenamiento.drop(MagicString.VEHICULOS_HEADER_TORQUE, axis=1, inplace=True)
Datos_para_entrenamiento.drop(MagicString.VEHICULOS_HEADER_SELLER_TYPE, axis=1, inplace=True)

# %%
# Reviso como quedaron mis datos para el entreamiento.
General.realizar_lectura_datos_analisis(Datos_para_entrenamiento,MagicString.CONFIGURACION_GENERAL_CANTIDAD_REGISTROS)
# Out:
#    year  selling_price  km_driven  fuel  transmission  owner  mileage  engine  \
# 0  2014         450000     145500     1             0      1       23    1248
# 1  2014         370000     120000     1             0      2       21    1498
# 2  2006         158000     140000     2             0      3       18    1497
# 3  2010         225000     127000     1             0      1       23    1396
# 4  2007         130000     120000     2             0      1       16    1298
#
#    max_power  seats
# 0         74      5
# 1        104      5
# 2         78      5
# 3         90      5
# 4         88      5

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna YEAR
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_YEAR,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_YEAR))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna Selling_Price
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_SELLING_PRICE,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_SELLING_PRICE))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna Km_Driven
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_KM_DRIVEN,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_KM_DRIVEN))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna MILEAGE
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_MILEAGE,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_MILEAGE))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna ENGINE
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_ENGINE,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_ENGINE))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna MAX POWER
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_MAX_POWER,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_MAX_POWER))

# %%
# Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna SEATS
General.generar_grafica_datos_obtenidos(Datos_modificados,MagicString.VEHICULOS_HEADER_SEATS,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_SEATS))

# %%
#Realizo una imputacion de datos para la columna Km Driven y Selling Price y los almaceno en una variable para utilizarlos mas adelante.
Datos_para_entrenamiento[MagicString.VEHICULOS_HEADER_KM_DRIVEN] = General.realizar_imputacion_de_datos_para_datos_atipicos(Datos_para_entrenamiento.copy(), MagicString.VEHICULOS_HEADER_KM_DRIVEN)
Datos_para_entrenamiento[MagicString.VEHICULOS_HEADER_SELLING_PRICE] = General.realizar_imputacion_de_datos_para_datos_atipicos(Datos_para_entrenamiento.copy(), MagicString.VEHICULOS_HEADER_SELLING_PRICE)

Datos_para_entrenamiento.describe()
# Out:
#        year  selling_price  km_driven  fuel  transmission  owner  mileage  \
# count  6717           6717       6717  6717          6717   6717     6717
# mean   2014         442546      68643     1             0      2       20
# std       4         247182      39261     1             0      1        4
# min    1994          29999          1     1             0      1        9
# 25%    2011         250000      38000     1             0      1       17
# 50%    2014         420000      68203     1             0      1       19
# 75%    2017         600000      96000     2             0      2       22
# max    2020        1250000     193000     4             1      5       42
#
#        engine  max_power  seats
# count    6717       6717   6717
# mean     1431         88      5
# std       493         32      1
# min       624         33      2
# 25%      1197         67      5
# 50%      1248         82      5
# 75%      1498        100      5
# max      3604        400     14

# %%
General.generar_grafica_datos_obtenidos(Datos_para_entrenamiento,MagicString.VEHICULOS_HEADER_KM_DRIVEN,MagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS.format(MagicString.VEHICULOS_HEADER_KM_DRIVEN))

# %%
# Utilizo los siguientes porcentajes para entrenamiento Train = 80% y Test = 20% tomando como referencia la columna TRANSMISSION
transmission_train_x, transmission_test_x, transmission_train_y, transmission_test_y = General.dividir_registros_train_y_test(Datos_para_entrenamiento, MagicString.VEHICULOS_HEADER_TRANSMISSION, 0)

# Obtengo la prediccion de mi modelo para Transmission
prediccion_trasmission = General.entrenar_modelo_regresion_logistica(transmission_train_x, transmission_train_y, transmission_test_x)
print(transmission_train_x)
print(transmission_train_y)
print(prediccion_trasmission)
# Out:
#       year  selling_price  km_driven  fuel  owner  mileage  engine  max_power  \
# 3124  2013         415000      60000     2      2       18    1197         86
# 3793  2013         325000     120000     1      1       24    1364         67
# 3293  2017         450000      40000     2      1       24     999         67
# 953   2016         535000      50000     1      1       20    1461         84
# 2372  2012         225000      87237     1      2       20    1399         68
# ...    ...            ...        ...   ...    ...      ...     ...        ...
# 5865  2011         275000      70000     2      3       18    1298         86
# 3748  2011         149000     148000     1      2       21    1248         89
# 1889  2006         120000     120000     2      4       20     796         46
# 2946  2018         409999      35000     2      2       24    1199         84
# 3076  2018         560000      25000     2      1       22    1197         82
#
#       seats
# 3124      5
# ...

# %%
# Evaluar el modelo de precision del modelo
General.evaluar_desempeño_modelo_presicion(prediccion_trasmission, transmission_test_y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      1236
#            1       0.76      0.24      0.37       108
#
#     accuracy                           0.93      1344
#    macro avg       0.85      0.62      0.67      1344
# weighted avg       0.92      0.93      0.92      1344

# %%
General.matriz_de_confusion(transmission_test_y, prediccion_trasmission)

# %%
# Generar Curva de Precision del modelo
General.curva_de_precision_modelo(transmission_test_y, prediccion_trasmission, MagicString.VEHICULOS_HEADER_TRANSMISSION)

# %%
# Utilizo los siguientes porcentajes para entrenamiento Train = 80% y Test = 20% tomando como referencia la columna OWNER
owner_train_x, owner_test_x, owner_train_y, owner_test_y = General.dividir_registros_train_y_test(Datos_para_entrenamiento, MagicString.VEHICULOS_HEADER_OWNER, 0)

# Obtengo la prediccion de mi modelo para Transmission
prediccion_owner = General.entrenar_modelo_regresion_logistica(owner_train_x, owner_train_y, owner_test_x)
print(owner_train_x)
print(owner_train_y)
print(prediccion_owner)
# Out:
#       year  selling_price  km_driven  fuel  transmission  mileage  engine  \
# 3124  2013         415000      60000     2             0       18    1197
# 3793  2013         325000     120000     1             0       24    1364
# 3293  2017         450000      40000     2             1       24     999
# 953   2016         535000      50000     1             0       20    1461
# 2372  2012         225000      87237     1             0       20    1399
# ...    ...            ...        ...   ...           ...      ...     ...
# 5865  2011         275000      70000     2             0       18    1298
# 3748  2011         149000     148000     1             0       21    1248
# 1889  2006         120000     120000     2             0       20     796
# 2946  2018         409999      35000     2             0       24    1199
# 3076  2018         560000      25000     2             0       22    1197
#
#       max_power  seats
# 3124         86      5
# 3793         67      5
# ...

# %%
# Evaluar el modelo de precision del modelo
General.evaluar_desempeño_modelo_presicion(prediccion_owner, owner_test_y)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.89      0.78       832
#            2       0.41      0.29      0.34       389
#            3       0.00      0.00      0.00        91
#            4       0.00      0.00      0.00        31
#            5       0.00      0.00      0.00         1
#
#     accuracy                           0.63      1344
#    macro avg       0.22      0.23      0.22      1344
# weighted avg       0.54      0.63      0.58      1344

# %%
# Generar Matriz de confusion
General.matriz_de_confusion(owner_test_y, prediccion_owner)

# %%
# Regresion Lineal.
General.regresion_lineal_obtener_intercepto_coeficiente(Datos_para_entrenamiento, MagicString.VEHICULOS_HEADER_KM_DRIVEN, MagicString.VEHICULOS_HEADER_SELLING_PRICE)
# Out:
# Intercepto BETA 0: 539001.731128893
# Coeficiente BETA 1: [-1.40517778]
# Kilometraje predicho para un carro con kilometraje 32478 = 493364.3673477611
# Kilometraje predicho para un carro con kilometraje 47852 = 471761.1642326949
# Kilometraje predicho para un carro con kilometraje 61203 = 453000.63575674524
# Kilometraje predicho para un carro con kilometraje 84756 = 419904.483618775
# Kilometraje predicho para un carro con kilometraje 122222 = 367258.093095224
# d:\Programs\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
