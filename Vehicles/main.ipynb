# %%
#Importo las librerias sys y os para tener un mejor control de archivos que se encuentran en mi solucion.
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

#Importo mi Clase con las constantes declaradas con las rutas y algunos mensajes que utilizare 
from constantes import ConstantesMagicString
from business_logic import BusinessRules

# %%
#Lectura de nuestro recurso CSV.
Datos = BusinessRules.leer_datos_csv(ConstantesMagicString.VEHICULOS_RUTA)

# %%
#Realizo la lectura de los datos para el analisis exploratorio
BusinessRules.realizar_lectura_datos_analisis(Datos,ConstantesMagicString.CONFIGURACION_GENERAL_CANTIDAD_REGISTROS)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
#Descripcion de los Datos.
BusinessRules.describir_datos_csv(Datos)
# Out:
#        year  selling_price  km_driven  seats
# count  8128           8128       8128   7907
# mean   2014         638272      69820      5
# std       4         806253      56551      1
# min    1983          29999          1      2
# 25%    2011         254999      35000      5
# 50%    2015         450000      60000      5
# 75%    2017         675000      98000      5
# max    2020       10000000    2360457     14

# %%
#Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna Selling_Price
BusinessRules.generar_graficas_datos_obtenidos(Datos,ConstantesMagicString.VEHICULOS_HEADER_SELLING_PRICE,ConstantesMagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS_SELLING_PRICE)

# %%
#Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna Km_Driven
BusinessRules.generar_graficas_datos_obtenidos(Datos,ConstantesMagicString.VEHICULOS_HEADER_KM_DRIVEN,ConstantesMagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS_KM_DRIVEN)

# %%
#Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna YEAR
BusinessRules.generar_graficas_datos_obtenidos(Datos,ConstantesMagicString.VEHICULOS_HEADER_YEAR,ConstantesMagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS_YEAR)

# %%
#Indentificacion de Datos Faltantes y Atípicos en nuestro recurso CSV para la columna SEATS
BusinessRules.generar_graficas_datos_obtenidos(Datos,ConstantesMagicString.VEHICULOS_HEADER_SEATS,ConstantesMagicString.VEHICULOS_MENSAJE_VALORES_ATIPICOS_SEATS)

# %%
BusinessRules.revision_datos_atipicos(Datos)
# Out:
# 20
